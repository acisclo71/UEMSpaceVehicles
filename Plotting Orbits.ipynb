# %%
from numpy import radians
from scipy.constants import kilo
from orbital import earth, KeplerianElements, Maneuver, plot, plot3d
from orbital import earth_sidereal_day
import matplotlib.pyplot as plt

# %%
molniya = KeplerianElements.with_period(
    earth_sidereal_day / 2, e=0.741, i=radians(63.4), arg_pe=radians(270),
    body=earth)

orbit = KeplerianElements.with_altitude(1000 * kilo, body=earth)
plot3d(molniya, title='Molniya 1', animate=True)
plt.show() #added
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 6>()
#       1 molniya = KeplerianElements.with_period(
#       2     earth_sidereal_day / 2, e=0.741, i=radians(63.4), arg_pe=radians(270),
#       3     body=earth)
#       5 orbit = KeplerianElements.with_altitude(1000 * kilo, body=earth)
# ----> 6 plot3d(molniya, title='Molniya 1', animate=True)
#       7 plt.show()
#
# File /opt/anaconda3/envs/AstroDynamics/lib/python3.9/site-packages/orbital/plotting.py:44, in plot3d(orbit, title, maneuver, animate, speedup)
#      42 plotter = Plotter3D()
#      43 if animate:
# ---> 44     return plotter.animate(orbit, title=title, speedup=speedup)
#      45 else:
#      46     plotter.plot(orbit, title=title, maneuver=maneuver)
#
# File /opt/anaconda3/envs/AstroDynamics/lib/python3.9/site-packages/orbital/plotting.py:219, in Plotter3D.animate(self, orbit, speedup, title)
#     215 def animate(self, orbit, speedup=5000, title=''):
#     216     # Copy orbit, because it will be modified in the animation callback.
#     217     orbit = copy(orbit)
# --> 219     self.plot(orbit)
#     221     num_points = self.points_per_rad * 2 * pi
#     222     f = np.linspace(0, 2 * pi, num_points)
#
# File /opt/anaconda3/envs/AstroDynamics/lib/python3.9/site-packages/orbital/plotting.py:196, in Plotter3D.plot(self, orbit, maneuver, title)
#     193 self._plot_body(orbit)
#     195 if maneuver is None:
# --> 196     self._plot_orbit(orbit)
#     197     self.pos_dot = self._plot_position(orbit)
#     198 else:
#
# File /opt/anaconda3/envs/AstroDynamics/lib/python3.9/site-packages/orbital/plotting.py:262, in Plotter3D._plot_orbit(self, orbit, f1, f2, label)
#     259     f2 += 2 * pi
#     261 num_points = self.points_per_rad * (f2 - f1)
# --> 262 f = np.linspace(f1, f2, num_points)
#     264 pos = self._xyz_coords(orbit, f)
#     265 x, y, z = pos[0, :], pos[1, :], pos[2, :]
#
# File <__array_function__ internals>:5, in linspace(*args, **kwargs)
#
# File /opt/anaconda3/envs/AstroDynamics/lib/python3.9/site-packages/numpy/core/function_base.py:120, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#      23 @array_function_dispatch(_linspace_dispatcher)
#      24 def linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None,
#      25              axis=0):
#      26     """
#      27     Return evenly spaced numbers over a specified interval.
#      28
#    (...)
#     118
#     119     """
# --> 120     num = operator.index(num)
#     121     if num < 0:
#     122         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer
