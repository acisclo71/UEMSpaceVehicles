# %%
from numpy import radians
from scipy.constants import kilo
from orbital import earth, KeplerianElements, Maneuver, plot, plot3d
from orbital import earth_sidereal_day
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from numpy import radians
#       2 from scipy.constants import kilo
# ----> 3 from orbital import earth, KeplerianElements, Maneuver, plot, plot3d
#       4 from orbital import earth_sidereal_day
#       5 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'earth' from 'orbital' (/Users/jgallegos/miniconda3/envs/SVM/lib/python3.10/site-packages/orbital/__init__.py)

# %%
molniya = KeplerianElements.with_period(
    earth_sidereal_day / 2, e=0.741, i=radians(63.4), arg_pe=radians(270),
    body=earth)

orbit = KeplerianElements.with_altitude(1000 * kilo, body=earth)
plot3d(molniya, title='Molniya 1', animate=True)
plt.show() #added
